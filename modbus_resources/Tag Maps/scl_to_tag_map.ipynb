# %%
import json, csv, os

# %%
# Added to the file name
project_number = '701'
if not os.path.exists(project_number):
    os.mkdir(project_number)

# Copy/pasted SCL code for assigning Modbus register values
scl = '''
// Subsystem States
//#MB_Hold_reg[1] := "PurifierWithHoistFb_DB".State;
#MB_Hold_Reg_Int[2] := "CH Liquefier_DB".State;
#MB_Hold_Reg_Int[3] := "Helium Recovery_DB".State;

// System Alarms 
#MB_Hold_Reg_Int[4] := "System Status".AlarmState;
//#MB_Hold_reg[5] := "PurifierWithHoistFb_DB".Alarm;
#MB_Hold_Reg_Int[6] := "CH Liquefier_DB".Alarm;
#MB_Hold_Reg_Int[7] := "Helium Recovery_DB".Alarm;
#MB_Hold_Reg_Int[8] := "Purity Meter_DB".Alarm;

// System Trips
#MB_Hold_Reg_Int[9] := "CH Liquefier_DB".Trip;
#MB_Hold_Reg_Int[10] := "Helium Recovery_DB".Trip;

// Purities
// #MB_Hold_Reg_Int[11] := "Purity Meter_DB"."Purity Downstream" * 100;
// #MB_Hold_Reg_Int[12] := "Purity Meter_DB"."Purity Upstream" * 100;
// #MB_Hold_Reg_Int[13] := "AIT501".AI.Value * 100;

// Analog Devices
// #MB_Hold_Reg_Int[14] := "DPT511".AI.Value * 10;
// #MB_Hold_Reg_Int[15] := "LT524".AI.Value2 * 10;
// #MB_Hold_Reg_Int[16] := "PT305".AI.Value * 10;
// #MB_Hold_Reg_Int[17] := "PT306".AI.Value * 100;
// #MB_Hold_Reg_Int[18] := "PT503".AI.Value * 10;
// #MB_Hold_Reg_Int[19] := "PT520".AI.Value * 100;
// #MB_Hold_Reg_Int[20] := "TE521".AI.Value * 100;
// #MB_Hold_Reg_Int[21] := "TE522".AI.Value * 100;
// #MB_Hold_Reg_Int[22] := "Alicat".AI.Value * 10;

// Digital Signals
#MB_Hold_Reg_Int[23] := BOOL_TO_INT("HE523");
//#MB_Hold_reg[24] := BOOL_TO_INT("HE527");
#MB_Hold_Reg_Int[25] := BOOL_TO_INT("XY301");
#MB_Hold_Reg_Int[26] := BOOL_TO_INT("XY302");
#MB_Hold_Reg_Int[27] := BOOL_TO_INT("XY303");
#MB_Hold_Reg_Int[28] := BOOL_TO_INT("MV301");
#MB_Hold_Reg_Int[29] := BOOL_TO_INT("XS403");
#MB_Hold_Reg_Int[30] := BOOL_TO_INT("LSL404");
#MB_Hold_Reg_Int[31] := BOOL_TO_INT("LSH402");
#MB_Hold_Reg_Int[32] := BOOL_TO_INT("XY512");
#MB_Hold_Reg_Int[33] := BOOL_TO_INT("XY513");
#MB_Hold_Reg_Int[34] := BOOL_TO_INT("XY514");
#MB_Hold_Reg_Int[35] := BOOL_TO_INT("XY515");
#MB_Hold_Reg_Int[36] := BOOL_TO_INT("XY416");
#MB_Hold_Reg_Int[37] := BOOL_TO_INT("M405DN");
#MB_Hold_Reg_Int[38] := BOOL_TO_INT("M405UP");
#MB_Hold_Reg_Int[39] := BOOL_TO_INT("XY501");
//#MB_Hold_reg[40] := BOOL_TO_INT("XY502");
#MB_Hold_Reg_Int[41] := BOOL_TO_INT("XY527");
#MB_Hold_Reg_Int[42] := BOOL_TO_INT("P501");
#MB_Hold_Reg_Int[43] := BOOL_TO_INT("XY520");
#MB_Hold_Reg_Int[44] := BOOL_TO_INT("XY521");
#MB_Hold_Reg_Int[45] := BOOL_TO_INT("CH Liquefier_DB".TransitionPurityMeter);

// Missed/Addendum Signals
//#MB_Hold_reg[46] := "TT901".AI.Value * 10;
#MB_Hold_Reg_Int[47] := BOOL_TO_INT("CH501_DB".Run_Feedback);
//#MB_Hold_reg[48] := BOOL_TO_INT("CH502_DB".Run_Feedback);
// #MB_Hold_Reg_Int[49] := "LT524".AI.Value2 * 10;
// #MB_Hold_reg[50] := "FirstStageTemperature".AI.Value * 10;

'''

# %%
'''Integers for StrideLinx'''

# Lists for the two tag tables that are populated in StrideLinx
# Variables: Used to access the register from the PLC
# Logging: Used to set the logging type and frequency of the variable
tag_map_variables = []
tag_map_logging = []

for line in iter(scl.splitlines()):
    # Skip line if it is empty or is a comment
    if line.strip(' ') == '':
        continue
    if line[0:2] == '//':
        continue
    
    # Get register portion and tag portion
    reg, tag = line.split(" := ")

    # Get the register index
    idx = int(reg[reg.find('[')+1:reg.rfind(']')])-1

    # Remove any comment at the end of the line
    tag = tag.split('//')[0]
    #Remove the end of line semicolon
    tag = tag.strip(';').replace('"', '')

    # Get the scaling value 
    if '*' in tag:
        tag, scale = tag.split(' * ')
    else:
        scale = 1
    
    # Check if the value is a bool conversion
    if 'BOOL_TO_INT' in tag:
        tag = tag[:-1]
        tag = tag.split('(')[1]
    
    # Save relevant information to the StrideLinx Variable tag map
    temp = {}
    temp['Identifier'] = ''
    temp['Name'] = tag
    temp['Address'] = idx
    temp['Type'] = 'int'
    temp['Width'] = 16
    temp['Signed'] = True
    temp['Max string length'] = ''
    temp['Factor'] = 1 / int(scale)
    temp['Unit'] = ''
    tag_map_variables.append(temp)

    # Save relevant information to the StrideLinx Logging tag map
    temp2 = {}
    temp2['Identifier'] = ''
    temp2['Address'] = idx
    temp2['Name'] = tag
    temp2['Logging interval'] = '10s'
    temp2['Retention policy'] = '364w'
    temp2['Edge aggregator'] = 'last'
    temp2['On change expiry'] = ''
    # Used to find tags that should be logged on change. Populate list with other signal names.
    if any(x in tag for x in ['XY', 'Run', 'Feedback', 'HE', 'Trip', 'Alarm', 'AlarmState', 'State', 'TransitionPurityMeter', 'MV', 'P501']):
        temp2['Log event'] = 'change'
    else:
        temp2['Log event'] = 'interval'
    temp2['Trigger address'] = ''
    temp2['Trigger condition'] = ''
    temp2['Trigger threshold'] = ''
    tag_map_logging.append(temp2)

# Save the variables to a csv that can be uploaded to the StrideLinx Fleet Manager
with open(project_number + '/' + project_number + '_StrideLinx_Int_Variables.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Identifier', 'Name', 'Address', 'Type', 'Width', 'Signed', 'Max string length', 'Factor', 'Unit'])
    writer.writeheader()
    writer.writerows(tag_map_variables)

# Save the logging tags to a csv that can be uploaded to the StrideLinx Fleet Manager
with open(project_number + '/' + project_number + '_StrideLinx_Int_Logging.csv', 'w', newline='') as f:
    # ['Identifier', 'Address', 'Name', 'Logging interval', 'Retention policy', 'Edge aggregator',	'On change expiry',	'Log event', 'Trigger address',	'Trigger condition', 'Trigger threshold'
    writer = csv.DictWriter(f, fieldnames=['Identifier', 'Address', 'Name', 'Logging interval', 'Retention policy', 'Edge aggregator',	'On change expiry',	'Log event', 'Trigger address',	'Trigger condition', 'Trigger threshold'])
    writer.writeheader()
    writer.writerows(tag_map_logging)

print(tag_map_variables)
# Out:
# [{'Identifier': '', 'Name': 'CH Liquefier_DB.State', 'Address': 1, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.State', 'Address': 2, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'System Status.AlarmState', 'Address': 3, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'CH Liquefier_DB.Alarm', 'Address': 5, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.Alarm', 'Address': 6, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'Purity Meter_DB.Alarm', 'Address': 7, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'CH Liquefier_DB.Trip', 'Address': 8, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.Trip', 'Address': 9, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'HE523', 'Address': 22, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY301', 'Address': 24, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY302', 'Address': 25, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY303', 'Address': 26, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'MV301', 'Address': 27, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XS403', 'Address': 28, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'LSL404', 'Address': 29, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'LSH402', 'Address': 30, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY512', 'Address': 31, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY513', 'Address': 32, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY514', 'Address': 33, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY515', 'Address': 34, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY416', 'Address': 35, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'M405DN', 'Address': 36, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'M405UP', 'Address': 37, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY501', 'Address': 38, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'XY527', 'Address': 40, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', 'Name': 'P501', 'Address': 41, 'Type': 'int', 'Width': 16, 'Signed': True, 'Max string length': '', 'Factor': 1.0, 'Unit': ''}, {'Identifier': '', ...

# %%
'''Reals for StrideLinx'''

# Lists for the two tag tables that are populated in StrideLinx
# Variables: Used to access the register from the PLC
# Logging: Used to set the logging type and frequency of the variable
tag_map_variables = []
tag_map_logging = []

for line in iter(scl.splitlines()):
    # Skip line if it is empty or is a comment
    if line.strip(' ') == '':
        continue
    if line[0:2] == '//':
        continue
    
    # Get register portion and tag portion
    reg, tag = line.split(" := ")

    # Get the register index
    idx = (int(reg[reg.find('[')+1:reg.rfind(']')])-1) * 2

    # Remove any comment at the end of the line
    tag = tag.split('//')[0]
    #Remove the end of line semicolon
    tag = tag.strip(';').replace('"', '')
    
    # Save relevant information to the StrideLinx Variable tag map
    temp = {}
    temp['Identifier'] = ''
    temp['Name'] = tag
    temp['Address'] = idx
    temp['Type'] = 'float'
    temp['Width'] = 32
    temp['Signed'] = ''
    temp['Max string length'] = ''
    temp['Factor'] = ''
    temp['Unit'] = ''
    tag_map_variables.append(temp)

    # Save relevant information to the StrideLinx Logging tag map
    temp2 = {}
    temp2['Identifier'] = ''
    temp2['Address'] = idx
    temp2['Name'] = tag
    temp2['Logging interval'] = '10s'
    temp2['Retention policy'] = '364w'
    temp2['Edge aggregator'] = 'last'
    temp2['On change expiry'] = ''
    # Used to find tags that should be logged on change. Populate list with other signal names.
    if any(x in tag for x in ['XY', 'Run', 'Feedback', 'HE', 'Trip', 'Alarm', 'AlarmState', 'State', 'TransitionPurityMeter', 'MV', 'P501']):
        temp2['Log event'] = 'change'
    else:
        temp2['Log event'] = 'interval'
    temp2['Trigger address'] = ''
    temp2['Trigger condition'] = ''
    temp2['Trigger threshold'] = ''
    tag_map_logging.append(temp2)

# Save the variables to a csv that can be uploaded to the StrideLinx Fleet Manager
with open(project_number + '/' + project_number + '_StrideLinx_Real_Variables.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Identifier', 'Name', 'Address', 'Type', 'Width', 'Signed', 'Max string length', 'Factor', 'Unit'])
    writer.writeheader()
    writer.writerows(tag_map_variables)

# Save the logging tags to a csv that can be uploaded to the StrideLinx Fleet Manager
with open(project_number + '/' + project_number + '_StrideLinx_Real_Logging.csv', 'w', newline='') as f:
    # ['Identifier', 'Address', 'Name', 'Logging interval', 'Retention policy', 'Edge aggregator',	'On change expiry',	'Log event', 'Trigger address',	'Trigger condition', 'Trigger threshold'
    writer = csv.DictWriter(f, fieldnames=['Identifier', 'Address', 'Name', 'Logging interval', 'Retention policy', 'Edge aggregator',	'On change expiry',	'Log event', 'Trigger address',	'Trigger condition', 'Trigger threshold'])
    writer.writeheader()
    writer.writerows(tag_map_logging)

print(tag_map_variables)
# Out:
# [{'Identifier': '', 'Name': 'CH Liquefier_DB.State', 'Address': 2, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.State', 'Address': 4, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'System Status.AlarmState', 'Address': 6, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'CH Liquefier_DB.Alarm', 'Address': 10, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.Alarm', 'Address': 12, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'Purity Meter_DB.Alarm', 'Address': 14, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'CH Liquefier_DB.Trip', 'Address': 16, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'Helium Recovery_DB.Trip', 'Address': 18, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(HE523)', 'Address': 44, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY301)', 'Address': 48, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY302)', 'Address': 50, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY303)', 'Address': 52, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(MV301)', 'Address': 54, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XS403)', 'Address': 56, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(LSL404)', 'Address': 58, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(LSH402)', 'Address': 60, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY512)', 'Address': 62, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY513)', 'Address': 64, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY514)', 'Address': 66, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY515)', 'Address': 68, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY416)', 'Address': 70, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(M405DN)', 'Address': 72, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(M405UP)', 'Address': 74, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY501)', 'Address': 76, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string length': '', 'Factor': '', 'Unit': ''}, {'Identifier': '', 'Name': 'BOOL_TO_INT(XY527)', 'Address': 80, 'Type': 'float', 'Width': 32, 'Signed': '', 'Max string leng ...

# %%
'''Use for sending CSV to customer'''

file_name = 'P654_tag_map'
tag_map = []

for line in iter(scl.splitlines()):
    # Skip line if it is empty or is a comment
    if line.strip(' ') == '':
        continue
    if line[0:2] == '//':
        continue
    
    # Get register portion and tag portion
    reg, tag = line.split(" := ")

    # Get the bit number if it exists
    if '.%X' in reg:
        bit = reg[-1]
    else:
        bit = None

    # Get the register index
    idx = int(reg[reg.find('[')+1:reg.rfind(']')])-1

    # Remove any comment at the end of the line
    tag = tag.split('//')[0]
    #Remove the end of line semicolon
    tag = tag.strip(';')
    # Get the scaling value 
    if '*' in tag:
        tag, scale = tag.split(' * ')
    else:
        scale = 1
    
    # Save relevant information to the output tag map
    temp = {}
    temp['index'] = idx
    temp['bit'] = bit
    temp['tag'] = tag
    temp['scale'] = int(scale) 
    tag_map.append(temp)

with open(file_name + '.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['index', 'tag', 'bit', 'scale'])
    writer.writeheader()
    writer.writerows(tag_map)

print(tag_map)
# Out:
# [{'index': 0, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 1, 'bit': None, 'tag': '"CB Liquefier_DB".State', 'scale': 1}, {'index': 2, 'bit': None, 'tag': '"Helium Recovery_DB".State', 'scale': 1}, {'index': 3, 'bit': None, 'tag': '"System Status".AlarmState', 'scale': 1}, {'index': 4, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 5, 'bit': None, 'tag': '"CB Liquefier_DB".Alarm', 'scale': 1}, {'index': 6, 'bit': None, 'tag': '"Helium Recovery_DB".Alarm', 'scale': 1}, {'index': 7, 'bit': None, 'tag': '"Purity Meter_DB".Alarm', 'scale': 1}, {'index': 8, 'bit': None, 'tag': '"CB Liquefier_DB".Trip', 'scale': 1}, {'index': 9, 'bit': None, 'tag': '"Helium Recovery_DB".Trip', 'scale': 1}, {'index': 10, 'bit': None, 'tag': '"HP Compressor_DB".State', 'scale': 1}, {'index': 11, 'bit': None, 'tag': '"HP Compressor_DB".Alarm', 'scale': 1}, {'index': 12, 'bit': None, 'tag': '"HP Compressor_DB".Trip', 'scale': 1}, {'index': 13, 'bit': None, 'tag': '"DPT508".AI.Value', 'scale': 100}, {'index': 14, 'bit': None, 'tag': '"LIT501".AI.Value2', 'scale': 10}, {'index': 15, 'bit': None, 'tag': '"PT214".AI.Value', 'scale': 100}, {'index': 16, 'bit': None, 'tag': '"PT409".AI.Value', 'scale': 100}, {'index': 17, 'bit': None, 'tag': '"PT503".AI.Value', 'scale': 100}, {'index': 18, 'bit': None, 'tag': '"PT504".AI.Value', 'scale': 100}, {'index': 19, 'bit': None, 'tag': '"PT505".AI.Value', 'scale': 100}, {'index': 20, 'bit': None, 'tag': '"PT506".AI.Value', 'scale': 100}, {'index': 21, 'bit': None, 'tag': '"PT1016".AI.Value', 'scale': 10}, {'index': 22, 'bit': None, 'tag': '"TE523".AI.Value', 'scale': 10}, {'index': 23, 'bit': None, 'tag': '"TE551".AI.Value', 'scale': 10}, {'index': 24, 'bit': None, 'tag': '"TE552".AI.Value', 'scale': 10}, {'index': 25, 'bit': None, 'tag': '"FC501".AI.Value', 'scale': 10}, {'index': 26, 'bit': None, 'tag': '"FC501_OUT".Value', 'scale': 10}, {'index': 27, 'bit': None, 'tag': '"FC502".AI.Value', 'scale': 10}, {'index': 28, 'bit': None, 'tag': '"FC502_OUT".Value', 'scale': 10}, {'index': 29, 'bit': None, 'tag': '"Purity Meter_DB"."Purity Downstream"', 'scale': 100}, {'index': 30, 'bit': None, 'tag': '"Purity Meter_DB"."Purity Upstream"', 'scale': 100}, {'index': 31, 'bit': None, 'tag': '"AIT501".AI.Value', 'scale': 100}, {'index': 32, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 33, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 34, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 35, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 36, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 37, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 38, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 39, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 40, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 41, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 42, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 43, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 44, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 45, 'bit': None, 'tag': '0', 'scale': 1}, {'index': 46, 'bit': '0', 'tag': '"Purity Meter_DB".DownstreamSamplingValve', 'scale': 1}, {'index': 46, 'bit': '1', 'tag': '"Purity Meter_DB".UpstreamSamplingValve', 'scale': 1}, {'index': 46, 'bit': '2', 'tag': '"CB Liquefier_DB".HighPressureVlv', 'scale': 1}, {'index': 46, 'bit': '3', 'tag': '"HP Compressor_DB".LSHH', 'scale': 1}, {'index': 46, 'bit': '4', 'tag': '"HP Compressor_DB".LSH', 'scale': 1}, {'index': 46, 'bit': '5', 'tag': '"HP Compressor_DB".LSL', 'scale': 1}, {'index': 46, 'bit': '6', 'tag': '"HP Compressor_DB".GasbagVentValve', 'scale': 1}, {'index': 46, 'bit': '7', 'tag': '"HP Compressor_DB".DC_OK', 'scale': 1}, {'index': 46, 'bit': '8', 'tag': '"HP Compressor_DB".HP_RunFB', 'scale': 1}]

# %%
'''JSON Export'''
# Serializing json
json_object = json.dumps(tag_map, indent=4)
 
# Writing to sample.json
with open("663_tag_map.json", "w") as outfile:
    outfile.write(json_object)

# %%
'''CSV Export'''
with open('654_tag_map.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['index', 'tag', 'bit', 'scale'])
    writer.writeheader()
    writer.writerows(tag_map)
